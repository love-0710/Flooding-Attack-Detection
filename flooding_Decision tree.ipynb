# %%
import pandas as pd
df = pd.read_csv('flooding.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398782 entries, 0 to 398781
# Data columns (total 18 columns):
#  #   Column                               Non-Null Count   Dtype
# ---  ------                               --------------   -----
#  0   time                                 398782 non-null  float64
#  1   source                               398782 non-null  int64
#  2   destination                          398782 non-null  int64
#  3   length                               398782 non-null  float64
#  4   info                                 398782 non-null  float64
#  5   transmission_rate_per_1000_ms        398782 non-null  float64
#  6   reception_rate_per_1000_ms           398782 non-null  float64
#  7   transmission_average_per_sec         398782 non-null  float64
#  8   reception_average_per_sec            398782 non-null  float64
#  9   transmission_count_per_sec           398782 non-null  float64
#  10  reception_count_per_sec              398782 non-null  float64
#  11  transmission_total_duration_per_sec  398782 non-null  float64
#  12  reception_total_duration_per_sec     398782 non-null  float64
#  13  dao                                  398782 non-null  float64
#  14  dis                                  398782 non-null  float64
#  15  dio                                  398782 non-null  float64
#  16  category                             398782 non-null  object
#  17  label                                398782 non-null  int64
# dtypes: float64(14), int64(3), object(1)
# memory usage: 54.8+ MB

# %%
df.head()
# Out:
#     time  source  destination  length  info  transmission_rate_per_1000_ms  \
# 0  0.000      39         9999     0.0   1.0                       0.455915
# 1  0.029      39         9999     0.0   1.0                       0.546376
# 2  0.031      39         9999     0.0   1.0                       0.477600
# 3  0.043      39         9999     0.0   1.0                       0.449653
# 4  0.045      39         9999     0.0   1.0                       0.554547
#
#    reception_rate_per_1000_ms  transmission_average_per_sec  \
# 0                    0.453760                      0.651939
# 1                    0.451854                      0.562410
# 2                    0.643320                      0.590334
# 3                    0.635719                      0.587023
# 4                    0.580181                      0.440554
#
#    reception_average_per_sec  transmission_count_per_sec  \
# 0                   0.602542                    0.455513
# 1                   0.574839                    0.546240
# 2                   0.550347                    0.477600
# 3                   0.513923                    0.449515
# 4                   0.520545                    0.554830
#
#    reception_count_per_sec  transmission_total_duration_per_sec  \
# 0                 0.453217                             0.647481
# 1                 0.451169                             0.639066
# 2                 0.644056                             0.495172
# 3                 0.636046                             0.452128
# 4                 0.580524                             0.422353
#
#    reception_total_duration_per_sec  dao  dis       dio  category  label
# 0                          1.000000  0.0  0.0  0.505311  Flooding      1
# 1                          0.417750  0.0  0.0  0.602969    Normal      0
# 2                          0.601483  0.0  0.0  0.672366    Normal      0
# 3                          0.558999  0.0  0.0  0.666124    Normal      0
# 4                          0.513192  0.0  0.0  0.698465    Normal      0

# %%
# Check if 'label' is in the columns
if 'label' in df.columns:
    print(df['label'].value_counts())
else:
    print("'label' column does not exist in the DataFrame.")
# Out:
# 0    263206
# 1    135576
# Name: label, dtype: int64

# %% [markdown]
# data preprocessing

# %%
from sklearn.model_selection import train_test_split
from imblearn.under_sampling import RandomUnderSampler
from sklearn.preprocessing import StandardScaler
from sklearn.manifold import TSNE  # Import t-SNE
import pandas as pd

# Assuming df is your DataFrame containing the dataset

# Instantiate StandardScaler
scalar = StandardScaler()

# Drop the 'category' column
X = df.drop(['label', 'category'], axis=1)  # Drop both the target variable and the categorical column
y = df['label']  # Target variable

# Store column names
column_names = X.columns.tolist()

# Apply t-SNE for dimensionality reduction
tsne = TSNE(n_components=2, random_state=23)  # Assuming 2 components for visualization
X_embedded = tsne.fit_transform(X)

# Split the embedded data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_embedded, y, test_size=0.2, random_state=23)

# Check value counts of 'label' column before undersampling
print("Value counts of 'label' column before undersampling:")
print(y_train.value_counts())

# Instantiate the random sampler for undersampling
undersampler = RandomUnderSampler(random_state=42)

# Balance only the training set
X_train_resampled, y_train_resampled = undersampler.fit_resample(X_train, y_train)

# Check value counts of 'label' column after undersampling
print("\nValue counts of 'label' column after undersampling:")
print(pd.Series(y_train_resampled).value_counts())

# Scale the embedded data
X_scaled = scalar.fit_transform(X_embedded)

# Convert the scaled data back to a DataFrame
X_scaled_df = pd.DataFrame(X_scaled, columns=['TSNE_Component_1', 'TSNE_Component_2'])

# Display the first 10 rows of the scaled data
print("First 10 rows of the scaled data:")
print(X_scaled_df.head(10))
# Out:
# Value counts of 'label' column before undersampling:
# 0    210552
# 1    108473
# Name: label, dtype: int64
#
# Value counts of 'label' column after undersampling:
# 0    108473
# 1    108473
# Name: label, dtype: int64
# First 10 rows of the scaled data:
#    TSNE_Component_1  TSNE_Component_2
# 0          0.275509         -1.433487
# 1          0.244476         -1.464260
# 2          0.236712         -1.470025
# 3          0.236584         -1.470331
# 4          0.237420         -1.469379
# 5          0.257990         -1.535311
# 6          0.240538         -1.466277
# 7          0.332879         -1.858781
# 8          0.237164         -1.469967
# 9          0.236803         -1.470210

# %%
import matplotlib.pyplot as plt

# Assuming X_scaled_df contains the preprocessed data with 'TSNE_Component_1' and 'TSNE_Component_2' columns

# Plot data points in the two-dimensional space with adjusted transparency
plt.figure(figsize=(8, 6))
plt.scatter(X_scaled_df['TSNE_Component_1'], X_scaled_df['TSNE_Component_2'], c=y, cmap='viridis', alpha=0.5)
plt.xlabel('TSNE_Component_1')
plt.ylabel('TSNE_Component_2')
plt.title('t-SNE Visualization')
plt.colorbar(label='Label')
plt.show()

# %%
import matplotlib.pyplot as plt

# Plot histograms for TSNE_Component_1
plt.figure(figsize=(10, 6))
plt.hist(X_scaled_df['TSNE_Component_1'], bins=30, alpha=0.5, color='blue')
plt.xlabel('TSNE_Component_1')
plt.ylabel('Frequency')
plt.title('Histogram of TSNE_Component_1')
plt.grid(True)
plt.show()

# Plot histograms for TSNE_Component_2
plt.figure(figsize=(10, 6))
plt.hist(X_scaled_df['TSNE_Component_2'], bins=30, alpha=0.5, color='green')
plt.xlabel('TSNE_Component_2')
plt.ylabel('Frequency')
plt.title('Histogram of TSNE_Component_2')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# Define colors for each class
colors = {0: 'blue', 1: 'red'}  # You can add more colors if you have more classes

# Plot data points in the two-dimensional space with separate colors for each class
plt.figure(figsize=(8, 6))
for label, color in colors.items():
    plt.scatter(X_scaled_df[y == label]['TSNE_Component_1'], X_scaled_df[y == label]['TSNE_Component_2'], 
                c=color, label=label, alpha=0.5)
plt.xlabel('TSNE_Component_1')
plt.ylabel('TSNE_Component_2')
plt.title('t-SNE Visualization')
plt.legend(title='Label')
plt.show()

# %% [markdown]
# Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier

# Initialize Decision Tree model
dt_model = DecisionTreeClassifier()

# Train the model
dt_model.fit(X_train_resampled, y_train_resampled)

# Make predictions
y_pred_dt = dt_model.predict(X_test)

# %% [markdown]
# checking Accuracy

# %%
from sklearn.metrics import accuracy_score

# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred_dt)

print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.9871359253733215

# %%
import joblib
# Save the best model to disk
joblib.dump(dt_model, 'dt_flooding_model.pkl')
# Out:
# ['dt_flooding_model.pkl']

# %%
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np
import pandas as pd
import seaborn as sns

# Make predictions using the best model
y_predict = dt_model.predict(X_test)

# Calculate confusion matrix
conf_matrix = confusion_matrix(y_test, y_predict, labels=[0, 1])

# Create DataFrame for confusion matrix
confusion = pd.DataFrame(conf_matrix, index=['is Normal', 'is flooding'], columns=['predicted normal', 'predicted flooding'])

# Visualize confusion matrix using heatmap
sns.heatmap(confusion, annot=True, fmt='d')

# Print classification report
print(classification_report(y_test, y_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99     52654
#            1       0.98      0.99      0.98     27103
#
#     accuracy                           0.99     79757
#    macro avg       0.98      0.99      0.99     79757
# weighted avg       0.99      0.99      0.99     79757

# %% [markdown]
# Correlation

# %%
import pandas as pd
import scipy.stats as stats

# Assuming your data is stored in a DataFrame called df
columns_of_interest = ['length', 'transmission_rate_per_1000_ms', 'reception_rate_per_1000_ms', 
                       'transmission_average_per_sec', 'reception_average_per_sec', 
                       'transmission_count_per_sec', 'reception_count_per_sec', 
                       'transmission_total_duration_per_sec', 'reception_total_duration_per_sec']

# Selecting only the numerical columns
numerical_data = df[columns_of_interest]

# Compute the Pearson correlation coefficient matrix
corr_matrix = numerical_data.corr()

# Display the correlation matrix
print(corr_matrix)
# Out:
#                                        length  transmission_rate_per_1000_ms  \
# length                               1.000000                       0.132811
# transmission_rate_per_1000_ms        0.132811                       1.000000
# reception_rate_per_1000_ms          -0.405757                       0.156110
# transmission_average_per_sec        -0.019259                       0.797060
# reception_average_per_sec           -0.208386                       0.105409
# transmission_count_per_sec           0.133961                       0.999987
# reception_count_per_sec             -0.404847                       0.156157
# transmission_total_duration_per_sec  0.202814                       0.099117
# reception_total_duration_per_sec    -0.597030                      -0.002579
#
#                                      reception_rate_per_1000_ms  \
# length                                                -0.405757
# transmission_rate_per_1000_ms                          0.156110
# reception_rate_per_1000_ms                             1.000000
# transmission_average_per_sec                           0.161668
# reception_average_per_sec                              0.762857
# transmission_count_per_sec                             0.155756
# reception_count_per_sec                                0.999991
# transmission_total_duration_per_sec                   -0.087532
# reception_total_duration_per_sec                       0.220247
#
#                                      transmission_average_per_sec  \
# length                                                  -0.019259
# transmission_rate_per_1000_ms                            0.797060
# reception_rate_per_1000_ms                               0.161668
# transmission_average_per_sec                             1.000000
# reception_average_per_sec                                0.145757
# transmission_count_per_sec                               0.796499
# reception_count_per_sec                                  0.161649
# transmission_total_duration_per_sec                      0.234573
# reception_total_duration_per_sec                         0.073074
#
#                                      reception_average_per_sec  \
# length                                               -0.208386
# transmission_rate_per_1000_ms                         0.105409
# reception_rate_per_1000_ms                            0.762857
# transmission_average_per_sec                          0.145757
# reception_average_per_sec                             1.000000
# transmission_count_per_sec                            0.105197
# reception_count_per_sec                               0.762544
# transmission_total_duration_per_sec                  -0.039066
# reception_total_duration_per_sec                      0.227091
#
#                                      transmission_count_per_sec  \
# length                                                 0.133961
# transmission_rate_per_1000_ms                          0.999987
# reception_rate_per_1000_ms                             0.155756
# transmission_average_per_sec                           0.796499
# reception_average_per_sec                              0.105197
# transmission_count_per_sec                             1.000000
# reception_count_per_sec                                0.155809
# transmission_total_duration_per_sec                    0.099276
# reception_total_duration_per_sec                      -0.003610
#
#                                      reception_count_per_sec  \
# length                                             -0.404847
# transmission_rate_per_1000_ms                       0.156157
# reception_rate_per_1000_ms                          0.999991
# transmission_average_per_sec                        0.161649
# reception_average_per_sec                           0.762544
# transmission_count_per_sec                          0.155809
# reception_count_per_sec                             1.000000
# transmission_total_duration_per_sec                -0.087541
# reception_total_duration_per_sec                    0.219313
#
#                                      transmission_total_duration_per_sec  \
# length                                                          0.202814
# transmission_rate_per_1000_ms                                   0.099117
# reception_rate_per_1000_ms                                     -0.087532
# transmission_average_per_sec                                    0.234573
# reception_average_per_sec                                      -0.039066
# transmission_count_per_sec                                      0.099276
# reception_count_per_sec                                        -0.087541
# transmission_total_duration_per_sec                             1.000000
# reception_total_duration_per_sec                               -0.058762
#
#                                      reception_total_duration_per_sec
# length                                                      -0.597030
# transmission_rate_per_1000_ms                               -0.002579
# reception_rate_per_1000_ms                                   0.220247
# transmission_average_per_sec                                 0.073074
# reception_average_per_sec                                    0.227091
# transmission_count_per_sec                                  -0.003610
# reception_count_per_sec                                      0.219313
# transmission_total_duration_per_sec                         -0.058762
# reception_total_duration_per_sec                             1.000000

# %%
# Compute the Spearman correlation coefficient matrix
spearman_corr_matrix = numerical_data.corr(method='spearman')

# Display the correlation matrix
print(spearman_corr_matrix)
# Out:
#                                        length  transmission_rate_per_1000_ms  \
# length                               1.000000                       0.322348
# transmission_rate_per_1000_ms        0.322348                       1.000000
# reception_rate_per_1000_ms          -0.544223                       0.047018
# transmission_average_per_sec        -0.080152                      -0.008996
# reception_average_per_sec           -0.073452                      -0.089433
# transmission_count_per_sec           0.324019                       0.999925
# reception_count_per_sec             -0.542030                       0.047824
# transmission_total_duration_per_sec  0.288362                       0.209112
# reception_total_duration_per_sec    -0.472323                      -0.154120
#
#                                      reception_rate_per_1000_ms  \
# length                                                -0.544223
# transmission_rate_per_1000_ms                          0.047018
# reception_rate_per_1000_ms                             1.000000
# transmission_average_per_sec                           0.051533
# reception_average_per_sec                              0.057050
# transmission_count_per_sec                             0.046346
# reception_count_per_sec                                0.999935
# transmission_total_duration_per_sec                   -0.213458
# reception_total_duration_per_sec                       0.306583
#
#                                      transmission_average_per_sec  \
# length                                                  -0.080152
# transmission_rate_per_1000_ms                           -0.008996
# reception_rate_per_1000_ms                               0.051533
# transmission_average_per_sec                             1.000000
# reception_average_per_sec                                0.077788
# transmission_count_per_sec                              -0.008548
# reception_count_per_sec                                  0.051549
# transmission_total_duration_per_sec                      0.382260
# reception_total_duration_per_sec                         0.024997
#
#                                      reception_average_per_sec  \
# length                                               -0.073452
# transmission_rate_per_1000_ms                        -0.089433
# reception_rate_per_1000_ms                            0.057050
# transmission_average_per_sec                          0.077788
# reception_average_per_sec                             1.000000
# transmission_count_per_sec                           -0.088962
# reception_count_per_sec                               0.056844
# transmission_total_duration_per_sec                  -0.117395
# reception_total_duration_per_sec                      0.323379
#
#                                      transmission_count_per_sec  \
# length                                                 0.324019
# transmission_rate_per_1000_ms                          0.999925
# reception_rate_per_1000_ms                             0.046346
# transmission_average_per_sec                          -0.008548
# reception_average_per_sec                             -0.088962
# transmission_count_per_sec                             1.000000
# reception_count_per_sec                                0.047175
# transmission_total_duration_per_sec                    0.209555
# reception_total_duration_per_sec                      -0.155681
#
#                                      reception_count_per_sec  \
# length                                             -0.542030
# transmission_rate_per_1000_ms                       0.047824
# reception_rate_per_1000_ms                          0.999935
# transmission_average_per_sec                        0.051549
# reception_average_per_sec                           0.056844
# transmission_count_per_sec                          0.047175
# reception_count_per_sec                             1.000000
# transmission_total_duration_per_sec                -0.212865
# reception_total_duration_per_sec                    0.304559
#
#                                      transmission_total_duration_per_sec  \
# length                                                          0.288362
# transmission_rate_per_1000_ms                                   0.209112
# reception_rate_per_1000_ms                                     -0.213458
# transmission_average_per_sec                                    0.382260
# reception_average_per_sec                                      -0.117395
# transmission_count_per_sec                                      0.209555
# reception_count_per_sec                                        -0.212865
# transmission_total_duration_per_sec                             1.000000
# reception_total_duration_per_sec                               -0.257662
#
#                                      reception_total_duration_per_sec
# length                                                      -0.472323
# transmission_rate_per_1000_ms                               -0.154120
# reception_rate_per_1000_ms                                   0.306583
# transmission_average_per_sec                                 0.024997
# reception_average_per_sec                                    0.323379
# transmission_count_per_sec                                  -0.155681
# reception_count_per_sec                                      0.304559
# transmission_total_duration_per_sec                         -0.257662
# reception_total_duration_per_sec                             1.000000

# %%
# Compute the Kendall tau correlation coefficient matrix
kendall_corr_matrix = numerical_data.corr(method='kendall')

# Display the correlation matrix
print(kendall_corr_matrix)
# Out:
# c:\Users\ADMIN\AppData\Local\Programs\Python\Python311\Lib\site-packages\scipy\stats\_stats_py.py:5278: RuntimeWarning: overflow encountered in longlong_scalars
#   (2 * xtie * ytie) / m + x0 * y0 / (9 * m * (size - 2)))
#                                        length  transmission_rate_per_1000_ms  \
# length                               1.000000                       0.234842
# transmission_rate_per_1000_ms        0.234842                       1.000000
# reception_rate_per_1000_ms          -0.407704                       0.035568
# transmission_average_per_sec        -0.060217                      -0.081024
# reception_average_per_sec           -0.064532                      -0.069695
# transmission_count_per_sec           0.236235                       0.998057
# reception_count_per_sec             -0.405961                       0.036183
# transmission_total_duration_per_sec  0.209043                       0.141806
# reception_total_duration_per_sec    -0.362679                      -0.106017
#
#                                      reception_rate_per_1000_ms  \
# length                                                -0.407704
# transmission_rate_per_1000_ms                          0.035568
# reception_rate_per_1000_ms                             1.000000
# transmission_average_per_sec                           0.033639
# reception_average_per_sec                             -0.019758
# transmission_count_per_sec                             0.035029
# reception_count_per_sec                                0.996796
# transmission_total_duration_per_sec                   -0.143902
# reception_total_duration_per_sec                       0.212329
#
#                                      transmission_average_per_sec  \
# length                                                  -0.060217
# transmission_rate_per_1000_ms                           -0.081024
# reception_rate_per_1000_ms                               0.033639
# transmission_average_per_sec                             1.000000
# reception_average_per_sec                                0.055096
# transmission_count_per_sec                              -0.080561
# reception_count_per_sec                                  0.033624
# transmission_total_duration_per_sec                      0.271975
# reception_total_duration_per_sec                         0.017673
#
#                                      reception_average_per_sec  \
# length                                               -0.064532
# transmission_rate_per_1000_ms                        -0.069695
# reception_rate_per_1000_ms                           -0.019758
# transmission_average_per_sec                          0.055096
# reception_average_per_sec                             1.000000
# transmission_count_per_sec                           -0.069346
# reception_count_per_sec                              -0.019974
# transmission_total_duration_per_sec                  -0.077844
# reception_total_duration_per_sec                      0.242132
#
#                                      transmission_count_per_sec  \
# length                                                 0.236235
# transmission_rate_per_1000_ms                          0.998057
# reception_rate_per_1000_ms                             0.035029
# transmission_average_per_sec                          -0.080561
# reception_average_per_sec                             -0.069346
# transmission_count_per_sec                             1.000000
# reception_count_per_sec                                0.035657
# transmission_total_duration_per_sec                    0.142160
# reception_total_duration_per_sec                      -0.107192
#
#                                      reception_count_per_sec  \
# length                                             -0.405961
# transmission_rate_per_1000_ms                       0.036183
# reception_rate_per_1000_ms                          0.996796
# transmission_average_per_sec                        0.033624
# reception_average_per_sec                          -0.019974
# transmission_count_per_sec                          0.035657
# reception_count_per_sec                             1.000000
# transmission_total_duration_per_sec                -0.143528
# reception_total_duration_per_sec                    0.210974
#
#                                      transmission_total_duration_per_sec  \
# length                                                          0.209043
# transmission_rate_per_1000_ms                                   0.141806
# reception_rate_per_1000_ms                                     -0.143902
# transmission_average_per_sec                                    0.271975
# reception_average_per_sec                                      -0.077844
# transmission_count_per_sec                                      0.142160
# reception_count_per_sec                                        -0.143528
# transmission_total_duration_per_sec                             1.000000
# reception_total_duration_per_sec                               -0.181983
#
#                                      reception_total_duration_per_sec
# length                                                      -0.362679
# transmission_rate_per_1000_ms                               -0.106017
# reception_rate_per_1000_ms                                   0.212329
# transmission_average_per_sec                                 0.017673
# reception_average_per_sec                                    0.242132
# transmission_count_per_sec                                  -0.107192
# reception_count_per_sec                                      0.210974
# transmission_total_duration_per_sec                         -0.181983
# reception_total_duration_per_sec                             1.000000

# %%
import numpy as np

# Compute the correlation coefficient matrix
corr_matrix = np.corrcoef(numerical_data, rowvar=False)

# Display the correlation matrix
print(corr_matrix)
# Out:
# [[ 1.          0.13281128 -0.40575697 -0.0192591  -0.20838637  0.13396073
#   -0.4048473   0.20281401 -0.59703002]
#  [ 0.13281128  1.          0.15611025  0.79706032  0.10540912  0.9999868
#    0.15615703  0.09911711 -0.00257873]
#  [-0.40575697  0.15611025  1.          0.1616679   0.76285666  0.15575559
#    0.99999103 -0.08753235  0.22024727]
#  [-0.0192591   0.79706032  0.1616679   1.          0.1457574   0.79649877
#    0.16164913  0.23457302  0.07307426]
#  [-0.20838637  0.10540912  0.76285666  0.1457574   1.          0.10519655
#    0.76254415 -0.03906634  0.22709132]
#  [ 0.13396073  0.9999868   0.15575559  0.79649877  0.10519655  1.
#    0.155809    0.09927613 -0.00361048]
#  [-0.4048473   0.15615703  0.99999103  0.16164913  0.76254415  0.155809
#    1.         -0.08754102  0.21931295]
#  [ 0.20281401  0.09911711 -0.08753235  0.23457302 -0.03906634  0.09927613
#   -0.08754102  1.         -0.05876236]
#  [-0.59703002 -0.00257873  0.22024727  0.07307426  0.22709132 -0.00361048
#    0.21931295 -0.05876236  1.        ]]

# %%
import pandas as pd
corr_coefficient = df['length'].corr(df['transmission_rate_per_1000_ms'])
print("Correlation coefficient between column1 and column2:", corr_coefficient)
# Out:
# Correlation coefficient between column1 and column2: 0.13281127758543176

# %%
spearman_corr = df['length'].corr(df['transmission_rate_per_1000_ms'], method='spearman')

kendall_corr = df['length'].corr(df['transmission_rate_per_1000_ms'], method='kendall')

print("Spearman correlation coefficient:", spearman_corr)
print("Kendall correlation coefficient:", kendall_corr)
# Out:
# Spearman correlation coefficient: 0.3223478011060625
# Kendall correlation coefficient: 0.2348419784212282
# c:\Users\ADMIN\AppData\Local\Programs\Python\Python311\Lib\site-packages\scipy\stats\_stats_py.py:5278: RuntimeWarning: overflow encountered in longlong_scalars
#   (2 * xtie * ytie) / m + x0 * y0 / (9 * m * (size - 2)))

# %%
# Select only numeric columns
numeric_df = df.select_dtypes(include='number')

# Compute the correlation matrix
correlation_matrix = numeric_df.corr()

print(correlation_matrix)
# Out:
#                                          time    source  destination  \
# time                                 1.000000 -0.087087    -0.152328
# source                              -0.087087  1.000000    -0.073714
# destination                         -0.152328 -0.073714     1.000000
# length                               0.439471  0.010262    -0.576445
# info                                -0.120523 -0.092404     0.886681
# transmission_rate_per_1000_ms        0.072638 -0.360569    -0.017776
# reception_rate_per_1000_ms          -0.096745 -0.071610     0.171672
# transmission_average_per_sec         0.042806 -0.169861     0.024901
# reception_average_per_sec            0.088133 -0.059797     0.194375
# transmission_count_per_sec           0.073090 -0.360936    -0.018490
# reception_count_per_sec             -0.096607 -0.071389     0.170840
# transmission_total_duration_per_sec  0.125026  0.012955    -0.237789
# reception_total_duration_per_sec    -0.147607 -0.079476     0.700128
# dao                                 -0.073339 -0.027957    -0.709043
# dis                                  0.362659 -0.093255     0.146839
# dio                                 -0.290894 -0.102930     0.589586
# label                               -0.238611 -0.091909     0.630845
#
#                                        length      info  \
# time                                 0.439471 -0.120523
# source                               0.010262 -0.092404
# destination                         -0.576445  0.886681
# length                               1.000000 -0.710209
# info                                -0.710209  1.000000
# transmission_rate_per_1000_ms        0.132811 -0.031834
# reception_rate_per_1000_ms          -0.405757  0.339230
# transmission_average_per_sec        -0.019259  0.046026
# reception_average_per_sec           -0.208386  0.234038
# transmission_count_per_sec           0.133961 -0.032838
# reception_count_per_sec             -0.404847  0.338226
# transmission_total_duration_per_sec  0.202814 -0.261345
# reception_total_duration_per_sec    -0.597030  0.713423
# dao                                  0.374440 -0.758517
# dis                                  0.608696 -0.058841
# dio                                 -0.818718  0.777699
# label                               -0.876742  0.832622
#
#                                      transmission_rate_per_1000_ms  \
# time                                                      0.072638
# source                                                   -0.360569
# destination                                              -0.017776
# length                                                    0.132811
# info                                                     -0.031834
# transmission_rate_per_1000_ms                             1.000000
# reception_rate_per_1000_ms                                0.156110
# transmission_average_per_sec                              0.797060
# reception_average_per_sec                                 0.105409
# transmission_count_per_sec                                0.999987
# reception_count_per_sec                                   0.156157
# transmission_total_duration_per_sec                       0.099117
# reception_total_duration_per_sec                         -0.002579
# dao                                                       0.265274
# dis                                                       0.235820
# dio                                                       0.166673
# label                                                    -0.086088
#
#                                      reception_rate_per_1000_ms  \
# time                                                  -0.096745
# source                                                -0.071610
# destination                                            0.171672
# length                                                -0.405757
# info                                                   0.339230
# transmission_rate_per_1000_ms                          0.156110
# reception_rate_per_1000_ms                             1.000000
# transmission_average_per_sec                           0.161668
# reception_average_per_sec                              0.762857
# transmission_count_per_sec                             0.155756
# reception_count_per_sec                                0.999991
# transmission_total_duration_per_sec                   -0.087532
# reception_total_duration_per_sec                       0.220247
# dao                                                   -0.154882
# dis                                                   -0.256262
# dio                                                    0.420132
# label                                                  0.402263
#
#                                      transmission_average_per_sec  \
# time                                                     0.042806
# source                                                  -0.169861
# destination                                              0.024901
# length                                                  -0.019259
# info                                                     0.046026
# transmission_rate_per_1000_ms                            0.797060
# reception_rate_per_1000_ms                               0.161668
# transmission_average_per_sec                             1.000000
# reception_average_per_sec                                0.145757
# transmission_count_per_sec                               0.796499
# reception_count_per_sec                                  0.161649
# transmission_total_duration_per_sec                      0.234573
# reception_total_duration_per_sec                         0.073074
# dao                                                      0.201157
# dis                                                      0.089466
# dio                                                      0.254066
# label                                                    0.058291
#
#                                      reception_average_per_sec  \
# time                                                  0.088133
# source                                               -0.059797
# destination                                           0.194375
# length                                               -0.208386
# info                                                  0.234038
# transmission_rate_per_1000_ms                         0.105409
# reception_rate_per_1000_ms                            0.762857
# transmission_average_per_sec                          0.145757
# reception_average_per_sec                             1.000000
# transmission_count_per_sec                            0.105197
# reception_count_per_sec                               0.762544
# transmission_total_duration_per_sec                  -0.039066
# reception_total_duration_per_sec                      0.227091
# dao                                                  -0.147422
# dis                                                  -0.047942
# dio                                                   0.183277
# label                                                 0.219854
#
#                                      transmission_count_per_sec  \
# time                                                   0.073090
# source                                                -0.360936
# destination                                           -0.018490
# length                                                 0.133961
# info                                                  -0.032838
# transmission_rate_per_1000_ms                          0.999987
# reception_rate_per_1000_ms                             0.155756
# transmission_average_per_sec                           0.796499
# reception_average_per_sec                              0.105197
# transmission_count_per_sec                             1.000000
# reception_count_per_sec                                0.155809
# transmission_total_duration_per_sec                    0.099276
# reception_total_duration_per_sec                      -0.003610
# dao                                                    0.265899
# dis                                                    0.236526
# dio                                                    0.165448
# label                                                 -0.087421
#
#                                      reception_count_per_sec  \
# time                                               -0.096607
# source                                             -0.071389
# destination                                         0.170840
# length                                             -0.404847
# info                                                0.338226
# transmission_rate_per_1000_ms                       0.156157
# reception_rate_per_1000_ms                          0.999991
# transmission_average_per_sec                        0.161649
# reception_average_per_sec                           0.762544
# transmission_count_per_sec                          0.155809
# reception_count_per_sec                             1.000000
# transmission_total_duration_per_sec                -0.087541
# reception_total_duration_per_sec                    0.219313
# dao                                                -0.154264
# dis                                                -0.255921
# dio                                                 0.419294
# label                                               0.401224
#
#                                      transmission_total_duration_per_sec  \
# time                                                            0.125026
# source                                                          0.012955
# destination                                                    -0.237789
# length                                                          0.202814
# info                                                           -0.261345
# transmission_rate_per_1000_ms                                   0.099117
# reception_rate_per_1000_ms                                     -0.087532
# transmission_average_per_sec                                    0.234573
# reception_average_per_sec                                      -0.039066
# transmission_count_per_sec                                      0.099276
# reception_count_per_sec                                        -0.087541
# transmission_total_duration_per_sec                             1.000000
# reception_total_duration_per_sec                               -0.058762
# dao                                                             0.242058
# dis                                                             0.045000
# dio                                                            -0.228198
# label                                                          -0.205858
#
#                                      reception_total_duration_per_sec  \
# time                                                        -0.147607
# source                                                      -0.079476
# destination                                                  0.700128
# length                                                      -0.597030
# info                                                         0.713423
# transmission_rate_per_1000_ms                               -0.002579
# reception_rate_per_1000_ms                                   0.220247
# transmission_average_per_sec                                 0.073074
# reception_average_per_sec                                    0.227091
# transmission_count_per_sec                                  -0.003610
# reception_count_per_sec                                      0.219313
# transmission_total_duration_per_sec                         -0.058762
# reception_total_duration_per_sec                             1.000000
# dao                                                         -0.528553
# dis                                                         -0.080534
# dio                                                          0.555012
# label                                                        0.657076
#
#                                           dao       dis       dio     label
# time                                -0.073339  0.362659 -0.290894 -0.238611
# source                              -0.027957 -0.093255 -0.102930 -0.091909
# destination                         -0.709043  0.146839  0.589586  0.630845
# length                               0.374440  0.608696 -0.818718 -0.876742
# info                                -0.758517 -0.058841  0.777699  0.832622
# transmission_rate_per_1000_ms        0.265274  0.235820  0.166673 -0.086088
# reception_rate_per_1000_ms          -0.154882 -0.256262  0.420132  0.402263
# transmission_average_per_sec         0.201157  0.089466  0.254066  0.058291
# reception_average_per_sec           -0.147422 -0.047942  0.183277  0.219854
# transmission_count_per_sec           0.265899  0.236526  0.165448 -0.087421
# reception_count_per_sec             -0.154264 -0.255921  0.419294  0.401224
# transmission_total_duration_per_sec  0.242058  0.045000 -0.228198 -0.205858
# reception_total_duration_per_sec    -0.528553 -0.080534  0.555012  0.657076
# dao                                  1.000000 -0.162402 -0.492167 -0.529897
# dis                                 -0.162402  1.000000 -0.397773 -0.427071
# dio                                 -0.492167 -0.397773  1.000000  0.816970
# label                               -0.529897 -0.427071  0.816970  1.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Select only numeric columns
numeric_df = df.select_dtypes(include='number')

# Compute the correlation matrix
correlation_matrix = numeric_df.corr()

# Create a heatmap
plt.figure(figsize=(10, 8))
plt.title('Correlation Matrix')
plt.imshow(correlation_matrix, cmap='coolwarm', interpolation='nearest')
plt.colorbar()
plt.xticks(range(len(correlation_matrix.columns)), correlation_matrix.columns, rotation=90)
plt.yticks(range(len(correlation_matrix.columns)), correlation_matrix.columns)
plt.show()

# %%
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

# Define the feature names based on the column names
feature_names = ['time', 'source', 'destination', 'length', 'info', 
                 'transmission_rate_per_1000_ms', 'reception_rate_per_1000_ms', 
                 'transmission_average_per_sec', 'reception_average_per_sec', 
                 'transmission_count_per_sec', 'reception_count_per_sec', 
                 'transmission_total_duration_per_sec', 'reception_total_duration_per_sec', 
                 'dao', 'dis', 'dio']

# Assuming best_model_dt is the decision tree model you want to visualize
plt.figure(figsize=(20,10))
plot_tree(dt_model, feature_names=feature_names, filled=True, max_depth=2, impurity=False, proportion=True)
plt.show()
